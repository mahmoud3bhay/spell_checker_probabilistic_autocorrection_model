# %% [markdown]
# # import required libraries.

# %%
import re
import string
from collections import Counter
import numpy as np

# %% [markdown]
# ## read text from file  as a dataset

# %%
def read_corpus(filename):
  with open(filename, "r+",encoding='cp1252') as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("/content/sherlock.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 106856 total words in the corpus

# %% [markdown]
# # **but them in a set to remove dublicates **

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 8071 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["love"])
# Out:
# 18

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["love"])
# Out:
# 0.00016845099947593022

# %% [markdown]
# # **splitting word **

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %% [markdown]
# # **delete one char at a time **

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %% [markdown]
# # **swap 2 chars at a time **

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %% [markdown]
# # **replace one char with another at a time **

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %% [markdown]
# # **insert a char at every position in the word**

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %% [markdown]
# # **remove duplicates from generated words**

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'triash', 'ttrash', 'tnrash', 'trafh', 'rtrash', 'trafsh', 'tkash', 'traeh', 'trasnh', 'tralsh', 'trasn', 'orash', 'tyrash', 'tzrash', 'tgash', 'irash', 'tnash', 'trqsh', 'trnash', 'qtrash', 'trsash', 'tyash', 'trarsh', 'trasmh', 'mtrash', 'traesh', 'tralh', 'travh', 'trasr', 'trabh', 'trazh', 'ftrash', 'traxsh', 'trasm', 'trash', 'trmsh', 'trasf', 'grash', 'tramh', 'trpash', 'tracsh', 'trasfh', 'traskh', 'trashp', 'tfrash', 'trcsh', 'trish', 'trvash', 'tqash', 'trashb', 'trashz', 'traksh', 'tmash', 'trzash', 'trashg', 'tprash', 'tcash', 'tranh', 'trast', 'tradsh', 'jtrash', 'trasvh', 'trashs', 'traph', 'trajh', 'trwsh', 'trasc', 'trahs', 'etrash', 'trqash', 'trashv', 'trnsh', 'trksh', 'trashi', 'tdrash', 'vtrash', 'wtrash', 'trasth', 'trasw', 'trakh', 'traoh', 'trtsh', 'trdash', 'tsrash', 'trashq', 'crash', 'trtash', 'trawh', 'trasy', 'tlrash', 'trashc', 'trasbh', 'trasih', 'trashf', 'xrash', 'tvrash', 'prash', 'trhash', 'trkash', 'erash', 'trasoh', 'trashj', 'trasho', 'trcash', 'srash', 'tqrash', 'urash', 'ztrash', 'thrash', 'trasdh', 'traxh', 'trach', 'brash', 'ltrash', 'tpash', 'traah', 'tjrash', 'traqsh', 'trasd', 'trasg', 'trashy', 'trasph', 'trasl', 'trfsh', 'tras', 'trashn', 'tratsh', 'tragh', 'xtrash', 'trxash', 'trashx', 'trosh', 'trasch', 'tgrash', 'trask', 'tfash', 'tuash', 'trysh', 'truash', 'trlsh', 'traysh', 'trasha', 'trahsh', 'tiash', 'nrash', 'utrash', 'trmash', 'troash', 'traqh', 'trapsh', 'yrash', 'trarh', 'tash', 'trpsh', 'taash', 'trass', 'tzash', 'tdash', 'traso', 'zrash', 'tlash', 'trasp', 'trxsh', 'trasx', 'btrash', 'rtash', 'dtrash', 'tarsh', 'drash', 'ytrash', 'twrash', 'trgash', 'toash', 'trazsh', 'trashl', 'trasq', 'trsah', 'trgsh', 'trhsh', 'trbash', 'tradh', 'trah', 'trasjh', 'trdsh', 'trashk', 'turash', 'torash', 'trzsh', 'teash', 'traih', 'trashe', 'trasuh', 'trasgh', 'tsash', 'tragsh', 'qrash', 'traish', 'trsh', 'frash', 'trasqh', 'trashr', 'ctrash', 'itrash', 'treash', 'rrash', 'htrash', 'trrash', 'transh', 'lrash', 'trbsh', 'trasxh', 'trahh', 'trasv', 'trjsh', 'vrash', 'tryash', 'arash', 'thash', 'trvsh', 'trjash', 'trabsh', 'trrsh', 'trush', 'trasi', 'trasht', 'tbash', 'tvash', 'trath', 'ntrash', 'traswh', 'trasu', 'tjash', 'twash', 'trashw', 'tresh', 'tkrash', 'trasyh', 'mrash', 'travsh', 'traosh', 'jrash', 'hrash', 'trauh', 'terash', 'trwash', 'trase', 'strash', 'trasj', 'trassh', 'trfash', 'trashh', 'trasah', 'trasrh', 'tirash', 'tmrash', 'trajsh', 'txash', 'trawsh', 'trssh', 'ptrash', 'traszh', 'trayh', 'trashu', 'tbrash', 'traseh', 'trasa', 'ttash', 'trashm', 'gtrash', 'txrash', 'krash', 'otrash', 'trlash', 'traslh', 'trasb', 'traush', 'tcrash', 'tramsh', 'trasz', 'tarash', 'ktrash', 'wrash', 'traash', 'trashd', 'rash', 'atrash'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'trbasph', 'trayesh', 'trzazh', 'trnoh', 'tvrafsh', 'trllsh', 'trmashe', 'trahhv', 'ftrashy', 'tragst', 'tiask', 'traqesh', 'brasth', 'truashu', 'tramsqh', 'iriash', 'rtruash', 'tirrsh', 'tartsh', 'trahhe', 'trdse', 'erauh', 'mjtrash', 'tqaksh', 'dtrsh', 'trasba', 'tqrashv', 'tifrash', 'trkzash', 'wtxash', 'trasyhy', 'trrsb', 'trcqash', 'tradhsh', 'trcas', 'mtrasmh', 'ztrach', 'cytrash', 'troahsh', 'eoash', 'traghsh', 'tqruash', 'srsah', 'taaish', 'tbyrash', 'ctralsh', 'traiuh', 'mravh', 'trasqgh', 'trawash', 'tnrach', 'trfasmh', 'trkmh', 'uraksh', 'omtrash', 'tmaih', 'etrkash', 'trcagsh', 'tzrlash', 'terasa', 'zrasl', 'trlmash', 'lttash', 'tmrashd', 'tnrgsh', 'tbawsh', 'tahrsh', 'trazdsh', 'traohp', 'wtrasoh', 'trasvhe', 'wtrvsh', 'treshc', 'thrqash', 'hrssh', 'aurash', 'trussh', 'xraash', 'tlraslh', 'mraah', 'etrashw', 'tfrpsh', 'trfvsh', 'trrasxh', 'ltrasi', 'zraqsh', 'pitrash', 'ytrashc', 'traizh', 'tyasz', 'jwtrash', 'travst', 'tmasb', 'gtrask', 'tasm', 'travsuh', 'otrasn', 'tkafsh', 'rtrhash', 'jtrashy', 'mtrnsh', 'xtpash', 'ftrosh', 'trfpsh', 'tprabsh', 'ytrpash', 'trasou', 'tlransh', 'traouh', 'trafsz', 'prosh', 'tmhsh', 'ctrasa', 'trxsoh', 'straxh', 'ltrawh', 'atkash', 'teransh', 'zlash', 'trzcsh', 'trdashc', 'tiraah', 'itrasch', 'jrasq', 'trisg', 'rtamh', 'tlrush', 'trzasbh', 'trtaqh', 'truyash', 'wrqash', 'tkashm', 'trpashy', 'trgeh', 'etrrash', 'trdashu', 'vtrush', 'wrpash', 'cyrash', 'tjaish', 'vztrash', 'irjsh', 'tqrasl', 'tjish', 'trwsz', 'trfyh', 'tvorash', 'mtraslh', 'tnzrash', 'trcashl', 'trasoho', 'atrzash', 'trcakh', 'treahh', 'cvtrash', 'tragshp', 'ltraoh', 'ktiash', 'tuasl', 'jrasd', 'tcgrash', 'rashv', 'tralk', 'twosh', 'pxtrash', 'twraih', 'trnvash', 'traswbh', 'tqrasph', 'trvshv', 'htorash', 'tryaph', 'trasg', 'tfaash', 'triaqh', 'travw', 'taaqh', 'tryashi', 'vtrlash', 'mrasyh', 'trdadsh', 'srdsh', 'trxasx', 'trasjx', 'trasax', 'tuish', 'trasmhw', 'tgrapsh', 'trasphz', 'xravsh', 'sdrash', 'xgtrash', 'ofrash', 'txxrash', 'trgsnh', 'rzash', 'tloash', 'etrssh', 'trjshq', 'htrashd', 'tryshx', 'tsasj', 'hfrash', 'krashg', 'jetrash', 'trasgo', 'xrqash', 'vtqrash', 'twerash', 'tragsq', 'trashif', 'ttabh', 'tarksh', 'trakqh', 'jtransh', 'ttrasrh', 'qtrbash', 'dtrasjh', 'tnrsh', 'tryagsh', 'tmrmash', 'tnasb', 'trosl', 'tuashy', 'ttashq', 'trajszh', 'atrnsh', 'tfraush', 'trtaeh', 'ttraqh', 'lralsh', 'krawsh', 'rtrcash', 'eroash', 'tdfsh', 'tryaysh', 'trgase', 'tyranh', 'tqrtsh', 'tvast', 'jtrdash', 'trlfsh', 'yrashf', 'tiarash', 'ctrxash', 'tqazh', 'trtsoh', 'trasmz', 'traoz', 'tracssh', 'tfashs', 'tveash', 'tyasa', 'trargsh', 'ktrash', 'tqbrash', 'tcrasu', 'treasy', 'terasho', 'htrcsh', 'txrasg', 'tktrash', 'traishr', 'tbaoh', 'trarshb', 'trtajh', 'tqast', 'tprashb', 'wrasx', 'lrashy', 'draysh', 'trrso', 'enash', 'trishb', 'trmsih', 'uzash', 'eurash', 'eradsh', 'trwajh', 'traxt', 'trast', 'trsoash', 'trdsfh', 'atraysh', 'ytrath', 'erassh', 'vtrasg', 'wterash', 'tewsh', 'traasn', 'lrasuh', 'drosh', 'trdaslh', 'trfswh', 'otrashs', 'trbyh', 'tdrasfh', 'mrach', 'skrash', 'trpseh', 'txbrash', 'yrasqh', 'qtraih', 'trasac', 'trmsl', 'ltrasx', 'arashr', 'ctzash', 'ftcrash', 'ptraesh', 'tjrash', 'traxsb', 'nttrash', 'traahx', 'tryasz', 'trlashz', 'otroash', 'tjrashf', 'ewrash', 'txuash', 'druash', 'thrazh', 'kthash', 'dtrashe', 'treasxh', 'trassi', 'ttraush', 'uctrash', 'trreh', 'fotrash', 'tramj', 'trjayh', 'traspah', 'tzrasc', 'tbafh', 'itorash', 'xmtrash', 'tsacsh', 'trabshi', 'mtxash', 'tzrish', 'trarhr', 'tqorash', 'tralc', 'trpaxh', 'frash', 'trlyh', 'btrtsh', 'tnrasj', 'tgrzsh', 'trfasj', 'trawrh', 'tfase', 'trzashz', 'trapw', 'itrbash', 'dtrdsh', 'tnrvsh', 'wtrasy', 'trsaih', 'trxsy', 'prafh', 'vtcash', 'trbzsh', 'tqesh', 'tarasyh', 'prush', 'tpasha', 'trcasz', 'lrasrh', 'trpsu', 'trmayh', 'trashh', 'rasch', 'ptrashl', 'jtrashq', 'fransh', 'utrasha', 'tnaih', 'trasnlh', 'triaslh', 'thraxsh', 'urjsh', 'tjrask', 'mzash', 'htraish', 'tbresh', 'trzshu', 'trabshx', 'xtratsh', 'atrajsh', 'troasho', 'wtdrash', 'tmashn ...

# %% [markdown]
# # keeping correct words

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")
# Out:
# [('family', 0.00028075166579321704)]
# family is suggested for famile

# %% [markdown]
# # **the whole program**

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r+",encoding='cp1252') as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters]

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("/content/sherlock.txt")

# %%
checker.check("sentense")
# Out:
# [('sentence', 3.74335554390956e-05)]
